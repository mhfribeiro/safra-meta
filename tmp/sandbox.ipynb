# %%
import pandas as pd
import scipy.stats as sts
from sklearn import preprocessing as prep
import numpy as np

df = pd.read_excel('cervejas.xlsx')

df
# Out:
#                         Nome               Tipo       País  Teor Alcoólico  \
# 0   Baden Baden American IPA                IPA     Brasil            6.40
# 1      Baden Baden Chocolate          Specialty     Brasil            6.00
# 2     Brewmeister Armaggedon  Strong Golden Ale    Escócia           65.00
# 3                    Crystal            Pilsner     Brasil            4.50
# 4           Delirium Tremens  Strong Golden Ale    Bélgica            8.50
# 5           Eisenbahn Pilsen            Pilsner     Brasil            4.80
# 6            Evil Twin Falco                IPA  Dinamarca            7.00
# 7           Golden Queen Bee  Strong Golden Ale    Bélgica            8.80
# 8             Kasteel Tripel            Trippel    Bélgica           11.00
# 9              Licher Weizen      German Weizen   Alemanha            5.40
# 10         Lohn Bier Trippel            Trippel     Brasil           10.40
# 11                      Skol            Pilsner     Brasil            4.60
# 12                     Lixol                IPA     Brasil            0.03
#
#     Volume Garrafa   Preço  Lixo
# 0              600   18.90    23
# 1              600   19.80    23
# 2              330  265.00    23
# 3              355    2.95    23
# 4              330   29.67    23
# 5              355    4.90    23
# 6              355   29.90    23
# 7              750  270.00    23
# 8              330   32.90    23
# 9              500   21.90    23
# 10             330   19.90    23
# 11             375    2.99    23
# 12              20    0.50    23

# %%
df.drop([2, 7, 12], inplace=True)
df.drop(columns=['Lixo'], inplace=True)

numeric_data = df._get_numeric_data()
maxima = numeric_data.max()
minima = numeric_data.min()

data_range = maxima - minima
data_range[data_range == 0] = 1.0

numeric_data = (numeric_data - minima) / data_range

df[numeric_data.columns] = numeric_data

df
# Out:
#                         Nome               Tipo       País  Teor Alcoólico  \
# 0   Baden Baden American IPA                IPA     Brasil        0.292308
# 1      Baden Baden Chocolate          Specialty     Brasil        0.230769
# 3                    Crystal            Pilsner     Brasil        0.000000
# 4           Delirium Tremens  Strong Golden Ale    Bélgica        0.615385
# 5           Eisenbahn Pilsen            Pilsner     Brasil        0.046154
# 6            Evil Twin Falco                IPA  Dinamarca        0.384615
# 8             Kasteel Tripel            Trippel    Bélgica        1.000000
# 9              Licher Weizen      German Weizen   Alemanha        0.138462
# 10         Lohn Bier Trippel            Trippel     Brasil        0.907692
# 11                      Skol            Pilsner     Brasil        0.015385
#
#     Volume Garrafa     Preço
# 0         1.000000  0.532554
# 1         1.000000  0.562604
# 3         0.092593  0.000000
# 4         0.000000  0.892154
# 5         0.092593  0.065109
# 6         0.092593  0.899833
# 8         0.000000  1.000000
# 9         0.629630  0.632721
# 10        0.000000  0.565943
# 11        0.166667  0.001336

# %%
le = prep.LabelEncoder()
stats = {}
for i,a in enumerate(df.columns):
    stats[a] = {}
    stats[a]['type'] = df.dtypes[i]
    ## Counting
    stats[a]['count'] = df[a].count()
    ## Non-unique values
    stats[a]['nunique'] = df[a].nunique()
    ## Mode
    mode = df[a].mode()
    if len(mode) == 1:
        stats[a]['mode'] = mode[0]
    else:
        stats[a]['mode'] = None
    
    if pd.api.types.is_numeric_dtype(df[a]):
        ## Entropy
        hist = np.histogram(df[a])[0]
        p = hist / np.sum(hist)
        stats[a]['entropy'] = sts.entropy(p)
        ## Variance
        stats[a]['variance'] = df[a].var()
        ## Average
        stats[a]['average'] = df[a].mean()
        ## Dispersion
        if stats[a]['average']:
            stats[a]['dispersion'] = stats[a]['variance']/stats[a]['average']
        else:
            stats[a]['dispersion'] = 0.0
        ## Standard deviation
        stats[a]['std_dev'] = df[a].std()
        ## Minimum and maximum
        stats[a]['min'] = df[a].min()
        stats[a]['max'] = df[a].max()
        ## Median
        stats[a]['median'] = df[a].median()
        ## Skewness and Kurtosis
        stats[a]['skewness'] = df[a].skew()
        stats[a]['kurtosis'] = df[a].kurt()
        ## Quantiles
        qts = df[a].quantile([0.25, 0.5, 0.75])
        stats[a]['quantile1'] = qts[0.25]
        stats[a]['quantile2'] = qts[0.5]
        stats[a]['quantile3'] = qts[0.75]
    else:
        tmp = le.fit_transform(df[a])
        hist = np.histogram(tmp)[0]
        p = hist / np.sum(hist)
        stats[a]['entropy'] = sts.entropy(p)
        stats[a]['variance'] = None
        stats[a]['average'] = None
        stats[a]['dispersion'] = None
        stats[a]['std_dev'] = None
        stats[a]['min'] = None
        stats[a]['max'] = None
        stats[a]['median'] = None
        stats[a]['skewness'] = None
        stats[a]['kurtosis'] = None
        stats[a]['quantile1'] = None
        stats[a]['quantile2'] = None
        stats[a]['quantile3'] = None
        
df_stats = pd.DataFrame.from_dict(stats, orient='index')

df_stats
# Out:
#                    type  count  nunique     mode   entropy  variance  \
# Nome             object     10       10     None  2.302585       NaN
# País             object     10        4   Brasil  1.088900       NaN
# Preço           float64     10       10     None  1.504788  0.141786
# Teor Alcoólico  float64     10       10     None  1.695743  0.132502
# Tipo             object     10        6  Pilsner  1.695743       NaN
# Volume Garrafa  float64     10        5     None  1.088900  0.167215
#
#                  average  dispersion   std_dev  min  max    median  skewness  \
# Nome                 NaN         NaN       NaN  NaN  NaN       NaN       NaN
# País                 NaN         NaN       NaN  NaN  NaN       NaN       NaN
# Preço           0.515225    0.275192  0.376545  0.0  1.0  0.564274 -0.357551
# Teor Alcoólico  0.363077    0.364943  0.364009  0.0  1.0  0.261538  0.864627
# Tipo                 NaN         NaN       NaN  NaN  NaN       NaN       NaN
# Volume Garrafa  0.307407    0.543954  0.408920  0.0  1.0  0.092593  1.174506
#
#                 kurtosis  quantile1  quantile2  quantile3
# Nome                 NaN        NaN        NaN        NaN
# País                 NaN        NaN        NaN        NaN
# Preço          -1.312956   0.181970   0.564274   0.827295
# Teor Alcoólico -0.590587   0.069231   0.261538   0.557692
# Tipo                 NaN        NaN        NaN        NaN
# Volume Garrafa -0.400974   0.023148   0.092593   0.513889

# %%
numeric_fields = df._get_numeric_data().columns

df_stats.loc[numeric_fields]
# Out:
#                    type  count  nunique  mode   entropy  variance   average  \
# Teor Alcoólico  float64     10       10  None  1.695743  0.132502  0.363077
# Volume Garrafa  float64     10        5  None  1.088900  0.167215  0.307407
# Preço           float64     10       10  None  1.504788  0.141786  0.515225
#
#                 dispersion   std_dev  min  max    median  skewness  kurtosis  \
# Teor Alcoólico    0.364943  0.364009  0.0  1.0  0.261538  0.864627 -0.590587
# Volume Garrafa    0.543954  0.408920  0.0  1.0  0.092593  1.174506 -0.400974
# Preço             0.275192  0.376545  0.0  1.0  0.564274 -0.357551 -1.312956
#
#                 quantile1  quantile2  quantile3
# Teor Alcoólico   0.069231   0.261538   0.557692
# Volume Garrafa   0.023148   0.092593   0.513889
# Preço            0.181970   0.564274   0.827295

# %%
from IPython.core.display import display, HTML
display(HTML('<h2 style="text-align:center">Stored Data Description</h2>' + df_stats.to_html()))

print('Stored Data Description\n' + str(df_stats))
# Out:
# <h2 style="text-align:center">Stored Data Description</h2><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>type</th>
#       <th>count</th>
#       <th>nunique</th>
#       <th>mode</th>
#       <th>entropy</th>
#       <th>variance</th>
#       <th>average</th>
#       <th>dispersion</th>
#       <th>std_dev</th>
#       <th>min</th>
#       <th>max</th>
#       <th>median</th>
#       <th>skewness</th>
#       <th>kurtosis</th>
#       <th>quantile1</th>
#       <th>quantile2</th>
#       <th>quantile3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Nome</th>
#       <td>object</td>
#       <td>10</td>
#       <td>10</td>
#       <td>None</td>
#       <td>2.302585</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>País</th>
#       <td>object</td>
#       <td>10</td>
#       <td>4</td>
#       <td>Brasil</td>
#       <td>1.088900</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Preço</th>
#       <td>float64</td>
#       <td>10</td>
#       <td>10</td>
#       <td>None</td>
#       <td>1.504788</td>
#       <td>0.141786</td>
#       <td>0.515225</td>
#       <td>0.275192</td>
#       <td>0.376545</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.564274</td>
#       <td>-0.357551</td>
#       <td>-1.312956</td>
#       <td>0.181970</td>
#       <td>0.564274</td>
#       <td>0.827295</td>
#     </tr>
#     <tr>
#       <th>Teor Alcoólico</th>
#       <td>float64</td>
#       <td>10</td>
#       <td>10</td>
#       <td>None</td>
#       <td>1.695743</td>
#       <td>0.132502</td>
#       <td>0.363077</td>
#       <td>0.364943</td>
#       <td>0.364009</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.261538</td>
#       <td>0.864627</td>
#       <td>-0.590587</td>
#       <td>0.069231</td>
#       <td>0.261538</td>
#       <td>0.557692</td>
#     </tr>
#     <tr>
#       <th>Tipo</th>
#       <td>object</td>
#       <td>10</td>
#       <td>6</td>
#       <td>Pilsner</td>
#       <td>1.695743</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Volume Garrafa</th>
#       <td>float64</td>
#       <td>10</td>
#       <td>5</td>
#       <td>None</td>
#       <td>1.088900</td>
#       <td>0.167215</td>
#       <td>0.307407</td>
#       <td>0.543954</td>
#       <td>0.408920</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>0.092593</td>
#       <td>1.174506</td>
#       <td>-0.400974</td>
#       <td>0.023148</td>
#       <td>0.092593</td>
#       <td>0.513889</td>
#     </tr>
#   </tbody>
# </table>
# Stored Data Description
#                    type  count  nunique     mode   entropy  variance  \
# Nome             object     10       10     None  2.302585       NaN
# País             object     10        4   Brasil  1.088900       NaN
# Preço           float64     10       10     None  1.504788  0.141786
# Teor Alcoólico  float64     10       10     None  1.695743  0.132502
# Tipo             object     10        6  Pilsner  1.695743       NaN
# Volume Garrafa  float64     10        5     None  1.088900  0.167215
#
#                  average  dispersion   std_dev  min  max    median  skewness  \
# Nome                 NaN         NaN       NaN  NaN  NaN       NaN       NaN
# País                 NaN         NaN       NaN  NaN  NaN       NaN       NaN
# Preço           0.515225    0.275192  0.376545  0.0  1.0  0.564274 -0.357551
# Teor Alcoólico  0.363077    0.364943  0.364009  0.0  1.0  0.261538  0.864627
# Tipo                 NaN         NaN       NaN  NaN  NaN       NaN       NaN
# Volume Garrafa  0.307407    0.543954  0.408920  0.0  1.0  0.092593  1.174506
#
#                 kurtosis  quantile1  quantile2  quantile3
# Nome                 NaN        NaN        NaN        NaN
# País                 NaN        NaN        NaN        NaN
# Preço          -1.312956   0.181970   0.564274   0.827295
# Teor Alcoólico -0.590587   0.069231   0.261538   0.557692
# Tipo                 NaN        NaN        NaN        NaN
# Volume Garrafa -0.400974   0.023148   0.092593   0.513889
